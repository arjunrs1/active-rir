# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output, display

# %%
a = np.load('/vision/asomaya1/active-rir/runs/SD_CA_early_cooldown_20k/tb/global_map.npy')

# %%
print(a.shape)
# Out:
# (1, 2, 241, 241)

# %%
""" plt.imshow(a[0][1], cmap='gray')
plt.show()
plt.imshow(a[0][0], cmap='gray')
plt.show()
plt.imshow(a[1][1], cmap='gray')
plt.show()
plt.imshow(a[1][0], cmap='gray')
plt.show()
plt.imshow(a[2][1], cmap='gray')
plt.show()
plt.imshow(a[2][0], cmap='gray')
plt.show() """
# Out:
# " plt.imshow(a[0][1], cmap='gray')\nplt.show()\nplt.imshow(a[0][0], cmap='gray')\nplt.show()\nplt.imshow(a[1][1], cmap='gray')\nplt.show()\nplt.imshow(a[1][0], cmap='gray')\nplt.show()\nplt.imshow(a[2][1], cmap='gray')\nplt.show()\nplt.imshow(a[2][0], cmap='gray')\nplt.show() "

# %%
""" for image in a:
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    # Display the first channel
    axes[0].imshow(image[0], cmap='gray')
    axes[0].set_title('Obstacle Map')

    # Display the second channel
    axes[1].imshow(image[1], cmap='gray')
    axes[1].set_title('Open Space Map')

    clear_output(wait=True)
    display(fig)

    plt.close(fig)  # Close the previous figure to release resources
    
    plt.show() """
# Out:
# " for image in a:\n    fig, axes = plt.subplots(1, 2, figsize=(12, 6))\n\n    # Display the first channel\n    axes[0].imshow(image[0], cmap='gray')\n    axes[0].set_title('Obstacle Map')\n\n    # Display the second channel\n    axes[1].imshow(image[1], cmap='gray')\n    axes[1].set_title('Open Space Map')\n\n    clear_output(wait=True)\n    display(fig)\n\n    plt.close(fig)  # Close the previous figure to release resources\n    \n    plt.show() "

# %%
while True:
    a = np.load('/vision/asomaya1/active-rir/runs/SD_C_map/tb/global_map.npy')[0]
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    # Display the first channel
    axes[0].imshow(a[0], cmap='gray')
    axes[0].set_title('Channel 1')

    # Display the second channel
    axes[1].imshow(a[1], cmap='gray')
    axes[1].set_title('Channel 2')

    clear_output(wait=True)
    display(fig)

    plt.close(fig)  # Close the previous figure to release resources
    print("usage")
    plt.show()
# Out:
# usage
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /vision/asomaya1/active-rir/ego_obs_vis.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2Bruohan/vision/asomaya1/active-rir/ego_obs_vis.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> while True:
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bruohan/vision/asomaya1/active-rir/ego_obs_vis.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     a = np.load('/vision/asomaya1/active-rir/runs/SD_C_map/tb/global_map.npy')[0]
#       <a href='vscode-notebook-cell://ssh-remote%2Bruohan/vision/asomaya1/active-rir/ego_obs_vis.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     fig, axes = plt.subplots(1, 2, figsize=(12, 6))
#       <a href='vscode-notebook-cell://ssh-remote%2Bruohan/vision/asomaya1/active-rir/ego_obs_vis.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     # Display the first channel
#
# ...

# %%
""" import numpy as np
for i in range(1,148):
    global_map = np.load('occupancy_vis_step_{}.npy'.format(i))
    # Display each channel as a separate subplot
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    # Display the first channel
    axes[0].imshow(global_map[0], cmap='gray')
    axes[0].set_title('Channel 1')

    # Display the second channel
    axes[1].imshow(global_map[1], cmap='gray')
    axes[1].set_title('Channel 2')
    plt.show() """
