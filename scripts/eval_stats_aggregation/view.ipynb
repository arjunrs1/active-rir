# %%
import matplotlib.pyplot as plt

# Data for plotting
# Formatting all observations for all metrics in code style

observations = list(range(1, 21))

# Metrics
stft_l1_distance = [
    0.022630963443468013, 0.022486026220334073, 0.02273960201224933, 0.02275466036517173, 
    0.022870038465286294, 0.02184812310927858, 0.021929215771767, 0.022019450676937898,
    0.021591101586818696, 0.02152448534810295, 0.021102077358712754, 0.02092386702230821,
    0.02084651281281064, 0.020931411581113935, 0.02095703042577952, 0.02096296049033602,
    0.02091489382243405, 0.0209443516874065, 0.020951196923851965, 0.020995289335648218
]

diff_rt_startFrom60dB = [
    0.16845989583333332, 0.16155624999999998, 0.14161197916666665, 0.13832239583333333,
    0.1331453125, 0.21086953125000002, 0.20276588541666665, 0.1934536458333333,
    0.2268546875, 0.23537760416666664, 0.2692231770833333, 0.29057057291666666,
    0.30470859375000003, 0.29339375, 0.2902921875, 0.29499479166666664,
    0.30111562500000005, 0.2965890625, 0.2958908854166667, 0.29241119791666664
]

diff_drr_3ms = [
    29.810505553211275, 29.83923198471573, 29.748529163237848, 29.728021304590637,
    29.70100868250983, 29.836161627991363, 29.821288198387418, 29.805294922650265,
    29.874899726617418, 29.891887590471764, 29.933587684980747, 29.932965707323685,
    29.922789968640465, 29.896188136847748, 29.86027569729538, 29.838357398583845,
    29.819147409083392, 29.789933988505076, 29.765084916723033, 29.740293742920013
]

rel_diff_rt_startFrom60dB = [
    0.7329432250443872, 0.7067348909375685, 0.6199248880467519, 0.6067480762899476,
    0.5841826905672687, 0.9133206767224756, 0.8785174441565479, 0.8386482753470792,
    0.9825987092432112, 1.0185283116507262, 1.1628751854093053, 1.2526097482137577,
    1.310952994216708, 1.2629996727351973, 1.2513022613684028, 1.2715469270612982,
    1.297995101828623, 1.278568046271974, 1.276084909508344, 1.261482476293729
]

# The metric where the error occurred: rel_diff_drr_3ms
rel_diff_drr_3ms = [
    0.8378280238955369, 0.8300929782242322, 0.8410271264348483, 0.8427397949168117,
    0.8457955492114146, 0.8298374184033748, 0.8315052360477861, 0.8329092844189152,
    0.8277914597734793, 0.8271460760812038, 0.8269098930457882, 0.8279758973855675,
    0.8296955047745112, 0.8328934003397651, 0.83753244049031, 0.840170430909765,
    0.8435840423032434, 0.8487863691399234, 0.8526137226266235, 0.8565083580064786
]

diff_ratio_lrEnergy = [
    2.758954604702873, 2.759191591074014, 2.7574545386094673, 2.758674893366587,
    2.7580854388367566, 2.763383839582252, 2.7629813013358264, 2.762371368204127,
    2.769022859014649, 2.770307336079353, 2.781949594106074, 2.7836785343612385,
    2.7849815422796853, 2.78387292593686, 2.7824395762424974, 2.781452847207504,
    2.7816145875359792, 2.7816608658319497, 2.7815267143035567, 2.7808160175980325
]

rel_diff_edt = [
    0.5530892360168411, 0.5470906302797222, 0.5557575357386372, 0.5601572539721427,
    0.5634831340487068, 0.5475992960836481, 0.5500090445041389, 0.5524892321836088,
    0.550488955955775, 0.5498166477473404, 0.5425569349868122, 0.5386236509893538,
    0.5358688266660948, 0.5377850242949075, 0.5385197191786202, 0.5382823653264837,
    0.5370219326796023, 0.5370884587213759, 0.536854368679273, 0.5374514671629077
]

# Updated code to display all metrics

plt.figure(figsize=(24, 12))

# STFT L1 Distance
plt.subplot(3, 3, 1)
plt.plot(observations, stft_l1_distance, marker='o')
plt.title('STFT L1 Distance')
plt.xlabel('Observation')
plt.ylabel('STFT L1 Distance')

# Difference RT Start From 60dB
plt.subplot(3, 3, 2)
plt.plot(observations, diff_rt_startFrom60dB, marker='o', color='r')
plt.title('Difference RT Start From 60dB')
plt.xlabel('Observation')
plt.ylabel('Diff RT StartFrom60dB')

# Difference DRR 3ms
plt.subplot(3, 3, 3)
plt.plot(observations, diff_drr_3ms, marker='o', color='g')
plt.title('Difference DRR 3ms')
plt.xlabel('Observation')
plt.ylabel('Diff DRR 3ms')

# Relative Difference RT Start From 60dB
plt.subplot(3, 3, 4)
plt.plot(observations, rel_diff_rt_startFrom60dB, marker='o', color='b')
plt.title('Relative Difference RT Start From 60dB')
plt.xlabel('Observation')
plt.ylabel('Rel Diff RT StartFrom60dB')

# Relative Difference DRR 3ms
plt.subplot(3, 3, 5)
plt.plot(observations, rel_diff_drr_3ms, marker='o', color='c')
plt.title('Relative Difference DRR 3ms')
plt.xlabel('Observation')
plt.ylabel('Rel Diff DRR 3ms')

# Difference Ratio LR Energy
plt.subplot(3, 3, 6)
plt.plot(observations, diff_ratio_lrEnergy, marker='o', color='m')
plt.title('Difference Ratio LR Energy')
plt.xlabel('Observation')
plt.ylabel('Diff Ratio LR Energy')

# Relative Difference EDT
plt.subplot(3, 3, 7)
plt.plot(observations, rel_diff_edt, marker='o', color='y')
plt.title('Relative Difference EDT')
plt.xlabel('Observation')
plt.ylabel('Rel Diff EDT')

plt.tight_layout()
plt.show()
