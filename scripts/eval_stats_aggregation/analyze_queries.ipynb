# %%
import os
import numpy as np
import pickle
from collections import Counter

# %%
with open("../../data/eval_arbitraryRIRQuery_datasets/mp3d/allEnv_14DatapointsPerEnv/test/60_qry/seenEnv_eval_798datapoints_subGraphIdxs_splitPerSubGraph.pkl", "rb") as f:
    subg_indxs = pickle.load(f)

# %%
with open("../../data/eval_arbitraryRIRQuery_datasets/mp3d/allEnv_14DatapointsPerEnv/test/60_qry/unseenEnv_eval_364datapoints_sceneNames.pkl", "rb") as f:
    queries = pickle.load(f)

# %%
a = Counter(queries)

# %%
queries = queries + queries

# %%
b = Counter(queries)

# %%
dict(a)
# Out:
# {'TbHJrupSAjP': 19,
#  'pa4otMbVnkk': 17,
#  'gYvKGZ5eRqb': 14,
#  'X7HyMhZNoso': 10,
#  'UwV83HsGsw3': 17,
#  'q9vSo1VnCiC': 12,
#  'zsNo4HB9uLZ': 14,
#  'pLe4wQe7qrG': 13,
#  'wc2JMjhGNzB': 14,
#  'x8F5xyUWy9e': 16,
#  'ARNzJeq3xxb': 13,
#  '8194nk5LbLH': 20,
#  'rqfALeAoiTq': 14,
#  '5ZKStnWn8Zo': 15,
#  'YFuZgdQ5vWj': 16,
#  'QUCTc6BB5sX': 11,
#  '2azQ1b91cZZ': 22,
#  'yqstnuAEVhm': 15,
#  'jtcxE69GiFV': 14,
#  'WYY7iVyf5p8': 8,
#  'gxdoqLR6rwA': 16,
#  'EU6Fwq7SyZv': 12,
#  'Vt2qJdWjCF2': 15,
#  'oLBMNvg9in8': 9,
#  'fzynW3qQPVF': 9,
#  'Z6MFQCViBuw': 9}

# %%
b
# Out:
# Counter({'2azQ1b91cZZ': 44,
#          '8194nk5LbLH': 40,
#          'TbHJrupSAjP': 38,
#          'pa4otMbVnkk': 34,
#          'UwV83HsGsw3': 34,
#          'x8F5xyUWy9e': 32,
#          'YFuZgdQ5vWj': 32,
#          'gxdoqLR6rwA': 32,
#          '5ZKStnWn8Zo': 30,
#          'yqstnuAEVhm': 30,
#          'Vt2qJdWjCF2': 30,
#          'gYvKGZ5eRqb': 28,
#          'zsNo4HB9uLZ': 28,
#          'wc2JMjhGNzB': 28,
#          'rqfALeAoiTq': 28,
#          'jtcxE69GiFV': 28,
#          'pLe4wQe7qrG': 26,
#          'ARNzJeq3xxb': 26,
#          'q9vSo1VnCiC': 24,
#          'EU6Fwq7SyZv': 24,
#          'QUCTc6BB5sX': 22,
#          'X7HyMhZNoso': 20,
#          'oLBMNvg9in8': 18,
#          'fzynW3qQPVF': 18,
#          'Z6MFQCViBuw': 18,
#          'WYY7iVyf5p8': 16})

# %%
with open("../../data/eval_arbitraryRIRQuery_datasets/mp3d/allEnv_14DatapointsPerEnv/test/60_qry/valid_context_percentages.npy", "rb") as f:
    pctgs = np.load(f)

# %%
len(pctgs) - 798
# Out:
# 364

# %%
364/14
# Out:
# 26.0
