# %%
import os
import numpy as np
import pickle
from collections import Counter

# %%
with open("../../data/eval_arbitraryRIRQuery_datasets/mp3d/allEnv_14DatapointsPerEnv/test/60_qry/seenEnv_eval_798datapoints_subGraphIdxs_splitPerSubGraph.pkl", "rb") as f:
    subg_indxs = pickle.load(f)

# %%
with open("../../data/eval_arbitraryRIRQuery_datasets/mp3d/allEnv_14DatapointsPerEnv/test/60_qry/seenEnv_eval_798datapoints_sceneNames.pkl", "rb") as f:
    queries = pickle.load(f)

# %%
a = Counter(queries)

# %%
queries = queries + queries

# %%
b = Counter(queries)

# %%
dict(a)
# Out:
# {'ULsKaCPVFJR': 21,
#  'jh4fc5c5qoQ': 19,
#  'Pm6F8kyY3z2': 16,
#  '7y3sRwLe3Va': 10,
#  '2n8kARJN3HM': 7,
#  'rPc6DW4iMge': 15,
#  'VLzqgDo317F': 10,
#  'qoiz87JEwZ2': 15,
#  'JmbYfDe2QKZ': 17,
#  'B6ByNegPMKs': 10,
#  'XcA2TqTSSAj': 19,
#  '1pXnuDYAj8r': 17,
#  '5q7pvUzZiYa': 16,
#  'D7G3Y4RVNrH': 13,
#  'VzqfbhrpDEA': 15,
#  'aayBHfsNo7d': 15,
#  'E9uDoFAP3SH': 17,
#  'vyrNrziPKCB': 17,
#  'p5wJjkQkbXX': 12,
#  'Vvot9Ly1tCj': 8,
#  'V2XKFyX4ASd': 23,
#  'JeFG25nYj2p': 17,
#  '8WUmhLawc2A': 18,
#  'b8cTxDM8gDG': 20,
#  'r47D5H71a5s': 11,
#  'ZMojNkEp431': 14,
#  'Uxmj2M2itWa': 19,
#  '5LpN3gDmAk7': 16,
#  'PX4nDJXEHrG': 12,
#  'pRbA3pwrgk9': 14,
#  'VFuaQ6m2Qom': 14,
#  'SN83YJsR3w2': 12,
#  'VVfe2KiqLaN': 17,
#  's8pcmisQ38h': 13,
#  'EDJbREhghzL': 14,
#  'ur6pFq6Qu1A': 9,
#  'kEZ7cmS4wCh': 11,
#  'D7N2EKCX4Sj': 11,
#  'GdvgFV5R1Z5': 11,
#  'sKLMLpTHeUy': 19,
#  'PuKPg4mmafe': 11,
#  '17DRP5sb8fy': 23,
#  'gTV8FGcVJC9': 12,
#  'ac26ZMwG7aT': 10,
#  'S9hNv5qa7GM': 13,
#  '1LXtFkjw3qL': 8,
#  'mJXqzFtmKg4': 8,
#  '759xd9YjKW5': 9,
#  'YmJkqBEsHnH': 16,
#  'e9zR4mvMWw7': 15,
#  'uNb9QFRL6hY': 12,
#  'sT4fr6TAbpF': 16,
#  '29hnd4uzFmX': 14,
#  '82sE5b5pLXE': 11,
#  'JF19kD82Mey': 19,
#  'cV4RVeZvu5T': 8,
#  'r1Q1Z4BcV1o': 9}

# %%
b
# Out:
# Counter({'V2XKFyX4ASd': 46,
#          '17DRP5sb8fy': 46,
#          'ULsKaCPVFJR': 42,
#          'b8cTxDM8gDG': 40,
#          'jh4fc5c5qoQ': 38,
#          'XcA2TqTSSAj': 38,
#          'Uxmj2M2itWa': 38,
#          'sKLMLpTHeUy': 38,
#          'JF19kD82Mey': 38,
#          '8WUmhLawc2A': 36,
#          'JmbYfDe2QKZ': 34,
#          '1pXnuDYAj8r': 34,
#          'E9uDoFAP3SH': 34,
#          'vyrNrziPKCB': 34,
#          'JeFG25nYj2p': 34,
#          'VVfe2KiqLaN': 34,
#          'Pm6F8kyY3z2': 32,
#          '5q7pvUzZiYa': 32,
#          '5LpN3gDmAk7': 32,
#          'YmJkqBEsHnH': 32,
#          'sT4fr6TAbpF': 32,
#          'rPc6DW4iMge': 30,
#          'qoiz87JEwZ2': 30,
#          'VzqfbhrpDEA': 30,
#          'aayBHfsNo7d': 30,
#          'e9zR4mvMWw7': 30,
#          'ZMojNkEp431': 28,
#          'pRbA3pwrgk9': 28,
#          'VFuaQ6m2Qom': 28,
#          'EDJbREhghzL': 28,
#          '29hnd4uzFmX': 28,
#          'D7G3Y4RVNrH': 26,
#          's8pcmisQ38h': 26,
#          'S9hNv5qa7GM': 26,
#          'p5wJjkQkbXX': 24,
#          'PX4nDJXEHrG': 24,
#          'SN83YJsR3w2': 24,
#          'gTV8FGcVJC9': 24,
#          'uNb9QFRL6hY': 24,
#          'r47D5H71a5s': 22,
#          'kEZ7cmS4wCh': 22,
#          'D7N2EKCX4Sj': 22,
#          'GdvgFV5R1Z5': 22,
#          'PuKPg4mmafe': 22,
#          '82sE5b5pLXE': 22,
#          '7y3sRwLe3Va': 20,
#          'VLzqgDo317F': 20,
#          'B6ByNegPMKs': 20,
#          'ac26ZMwG7aT': 20,
#          'ur6pFq6Qu1A': 18,
#          '759xd9YjKW5': 18,
#          'r1Q1Z4BcV1o': 18,
#          'Vvot9Ly1tCj': 16,
#          '1LXtFkjw3qL': 16,
#          'mJXqzFtmKg4': 16,
#          'cV4RVeZvu5T': 16,
#          '2n8kARJN3HM': 14})

# %%
with open("../../data/eval_arbitraryRIRQuery_datasets/mp3d/allEnv_14DatapointsPerEnv/test/60_qry/valid_context_percentages.npy", "rb") as f:
    pctgs = np.load(f)

# %%
len(pctgs) - 798
# Out:
# 364

# %%
364/14
# Out:
# 26.0
